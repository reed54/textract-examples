# %% [markdown]
# # Amazon Textract
# ### Reading a Journal Article
#
# **Based on Example found in** [AWS Textract Developer Guide](https://docs.aws.amazon.com/textract/latest/dg/textract-dg.pdf#examples-blocks)
#
# ![Amazon](https://media.gettyimages.com/photos/closeup-of-sign-with-logo-on-facade-of-the-regional-headquarters-of-picture-id1065011338?s=2048x2048)
#
#
# ### Article Title Page
#
# ![Ethical Concerns Regarding Twitter Data in Research](../data/research_title_page.png)

# %% [markdown]
# #### Import AWS API Library (boto3)

# %%
import boto3
import time
def startJob(s3BucketName, objectName):
    response = None
    client = boto3.client('textract')
    response = client.start_document_text_detection(
    DocumentLocation={
    'S3Object': {
    'Bucket': s3BucketName,
    'Name': objectName
         }
     })
    return response["JobId"]


def isJobComplete(jobId):
    # For production use cases, use SNS based notification 
    # Details at: https://docs.aws.amazon.com/textract/latest/dg/api-async.html
    time.sleep(5)
    client = boto3.client('textract')
    response = client.get_document_text_detection(JobId=jobId)
    status = response["JobStatus"]
    print("Job status: {}".format(status))
    while(status == "IN_PROGRESS"):
        time.sleep(5)
        response = client.get_document_text_detection(JobId=jobId)
        status = response["JobStatus"]
        print("Job status: {}".format(status))
    return status

def getJobResults(jobId):
    pages = []
    client = boto3.client('textract')
    response = client.get_document_text_detection(JobId=jobId)

    pages.append(response)
    print("Resultset page recieved: {}".format(len(pages)))
    nextToken = None
    if('NextToken' in response):
        nextToken = response['NextToken']
    while(nextToken):
        response = client.get_document_text_detection(JobId=jobId, NextToken=nextToken)
        pages.append(response)
        print("Resultset page recieved: {}".format(len(pages)))
        nextToken = None
        if('NextToken' in response):
            nextToken = response['NextToken']
    return pages

# Document
s3BucketName = "jdreed-hadley"
documentName = "The_Ethical_Challenges_Publishing_Twitter.pdf"

output_file = 'pdf_extract.txt'

jobId = startJob(s3BucketName, documentName)
print("Started job with id: {}".format(jobId))
if(isJobComplete(jobId)):
    response = getJobResults(jobId)
    
    # Print detected text
    with open(output_file, "wt") as f:
        for resultPage in response:
            for item in resultPage["Blocks"]:
                if item["BlockType"] == "LINE":
                    f.write('\033[94m' + item["Text"] + '\033[0m\n')

    # show the results
    print(f'\n\nPDF Extract OUTPUT FILE: {output_file}')
# Out:
# Started job with id: f817424c441392157354d7383dc856b51d6828aa8cb12eafe4815541704e0870
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: IN_PROGRESS
# Job status: SUCCEEDED
# Resultset page recieved: 1
# Resultset page recieved: 2
# Resultset page recieved: 3
# Resultset page recieved: 4
# Resultset page recieved: 5
# Resultset page recieved: 6
# Resultset page recieved: 7
# Resultset page recieved: 8
# Resultset page recieved: 9
# Resultset page recieved: 10
#
#
# PDF Extract OUTPUT FILE: pdf_extract.txt

# %%
# !head pdf_extract.txt
# Out:
# Long Session VI: Reflecting, Thinking, UnderstandingWebSci '17, June 25-28, 2017, Troy, NY, USAThe Ethical Challenges of Publishing Twitter Datafor Research DisseminationHelena WebbBernd Carsten StahlWilliam HousleyMarina JirotkaDe Montfort University,Adam EdwardsUniversity of Oxford,Department of InformaticsMatthew WilliamsDepartment of Computer ScienceLeicester, United KingdomCardiff University,Oxford, United Kingdombstahl@dmu.ac.ukSchool of Social Scienceshelena.webb@cs.ox.ac.ukCardiff, United Kingdommarina.jirotka.cs.ox.ac.ukOmer Ranahousleyw@cardiff.ac.ukPete Burnapedwardsa2@cardiff.ac.ukRob Procter*Cardiff University, Schoolwilliamsm7@cardiff.ac.ukUniversity of Warwick,of Computer Science and InformaticsDepartment of Computer ScienceCardiff, United KingdomCoventry, United Kingdomranaof@cardiff.ac.ulrob.procter@warwick.ac.ukp.burnap@cs.cardiff.ac.ul*Corresponding authorABSTRACTfields over how to resolve these issues and we argue thatEmpirical research involving the analysis of Internet-based dataconstructive debate is necessary in order to take a proactiveraises a number of ethical challenges. One instance of this is theapproach towards good practice.analysis of Twitter data, in particular when specific tweets arereproduced for the purposes of dissemination. Although TwitterKeywordsis an open platform it is possible to question whether thisResearch ethics, Twitter, social media, informed consentprovides a sufficient ethical justification to collect, analyse andreproduce tweets for the purposes of research or whether it is1. INTRODUCTIONnecessary to also undertake specific informed consentTwitter provides a highly popular data source in Web scienceprocedures. This paper reports on an ethics consultation thatresearch. It is easy to understand why this is the case. Twitter isformed part of a wider research study and that aimed to identifya widely used social media platform across the world and it isbest practice procedures for the publication of Twitter data inrelatively easy for researchers to collect data from it. As an openresearch findings. We focus largely on the UK context and drawplatform the majority of posts are available to public view andon the outcomes of the consultation to highlight the range andresearchers can collect large numbers of tweets in a very shortdepth of ethical issues that arise in this area. We can see Twitterperiod of time via the platform's Application Programmingas a case study for a wide number of data sources used in WebInterface (API). Much existing work draws upon large scaleScience. This is a highly complex landscape in which questionsquantitative approaches which present aggregated findings tocrystallise around fundamental principles such as informeddiscuss, for instance, voting intentions [1], the propagation ofconsent, anonymisation and the minimisation of harm.content [2], and the expression of sentiment and tension inFurthermore, tensions exist between commercial, regulatory andparticular social contexts [3]. Twitter data have also been usedacademic practices, and there are also circumstances in whichfor smaller scale qualitative analyses [4], which often usegood ethical practice might compromise academic integrity.linguistic or discourse analytic approaches to examine how postsThere is an absence of consensus in Web science and relatedare constructed and how the messages within them areconveyed.ccBYThis work is licensed under a Creative CommonsResearch in the field has already highlighted some of the ethicalAttribution International 4.0 Licenseissues involved in this kind of research - much of it in terms ofsocial media data as an instance of Big Data [5]. These importantWebSci '17, June 25-28, 2017, Troy, NY, USAdiscussions focus on concerns arising from the use of automated@ 2017 Copyright is held by the owner/author(s).processes to collect large volumes of data and what implicationsACM ISBN 978-1-4503-4896-6/17/06.this has for participant recruitment, privacy and identificationhtt ...
